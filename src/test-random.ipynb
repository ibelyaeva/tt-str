# %%
import numpy as np

# %%
np.random.rand(53,63,46,144)
# Out:
# array([[[[0.40299566, 0.11614737, 0.02806414, ..., 0.78574615,
#           0.28100114, 0.81769782],
#          [0.38965397, 0.58302397, 0.34192297, ..., 0.56026472,
#           0.71243842, 0.05538927],
#          [0.63432278, 0.41048465, 0.33974518, ..., 0.00960831,
#           0.86584616, 0.88588661],
#          ...,
#          [0.7064826 , 0.98876958, 0.2502325 , ..., 0.82612187,
#           0.75194686, 0.05619753],
#          [0.66948366, 0.58954888, 0.95045931, ..., 0.91193202,
#           0.06457639, 0.29328643],
#          [0.42847973, 0.46282846, 0.39451866, ..., 0.35819686,
#           0.86800513, 0.21065174]],
#
#         [[0.94339491, 0.13826625, 0.80200136, ..., 0.0554428 ,
#           0.13518085, 0.29241424],
#          [0.56220703, 0.05578751, 0.94788718, ..., 0.15194319,
#           0.46659454, 0.09033697],
#          [0.25479859, 0.1397216 , 0.18145559, ..., 0.06518833,
#           0.04566276, 0.98052526],
#          ...,
# ...
